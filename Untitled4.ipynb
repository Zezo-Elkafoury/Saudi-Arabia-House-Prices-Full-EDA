# %% [markdown]
# <a href="https://colab.research.google.com/github/Zezo-Elkafoury/Saudi-Arabia-House-Prices-Full-EDA/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import google.generativeai as genai
from langchain.vectorstores import FAISS
from langchain.text_splitter import RecursiveCharacterTextSplitter  # Improved Arabic handling
from langchain.embeddings import HuggingFaceEmbeddings

# Initialize HuggingFaceEmbeddings with Arabic support
hf_embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2")

# Configure Gemini API
genai.configure(api_key="AIzaSyAPlH0QYNq-bAManF02KQ1fSjvhp4H_bfs")  # Replace with your actual API key
gemini_model = genai.GenerativeModel("gemini-1.5-flash")

# Function to extract text from a JSON file
def extract_text_from_json(json_path):
    with open(json_path, 'r', encoding='utf-8') as file:
        data = json.load(file)
        text = json.dumps(data, ensure_ascii=False, indent=2)  # Arabic characters preserved
    return text

# Load text from JSON
json_path = "/content/konbert-output-efe6d469.json"  # Replace with your JSON filename
json_text = extract_text_from_json(json_path)

# Improved text splitting for Arabic text
splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50, separators=[".", "؟", "!", "\n"])
text_chunks = splitter.split_text(json_text)

# Store text embeddings in FAISS
vector_store = FAISS.from_texts(text_chunks, hf_embeddings)

# Function to retrieve relevant text from JSON
def retrieve_relevant_text(query):
    results = vector_store.similarity_search(query, k=3)
    return " ".join([doc.page_content for doc in results])

# Function to ask Gemini with retrieved JSON context
def ask_gemini(query):
    context = retrieve_relevant_text(query)
    prompt = f"استنادًا إلى البيانات التالية:\n{context}\nأجب عن هذا السؤال: {query}"

    response = gemini_model.generate_content(prompt)
    return response.text if hasattr(response, "text") else response

# Chatbot Loop
print(": مساعد الذكاء الاصطناعي ")
print("اكتب 'خروج' لإنهاء المحادثة.\n")

while True:
    user_input = input("أنت: ")
    if user_input.lower() == "خروج":
        print(": إلى اللقاء! 🌱")
        break

    response = ask_gemini(user_input)
    print(f"EcoBot: {response}\n")
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.89k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/471M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# EcoBot 🌿: مساعد الذكاء الاصطناعي للبيانات البيئية
# اكتب 'خروج' لإنهاء المحادثة.
#
# أنت: منحة جامعة النيل في مصر لدراسة الماجستير
# EcoBot: تقدم جامعة النيل في مصر منحة ماجستير في مجالات المعلوماتية، وأمن المعلومات، وهندسة البرمجيات.  لم يتم ذكر تفاصيل أخرى عن المنحة مثل الموعد النهائي للتقديم أو طريقة التقديم في البيانات المُقدمة.
#
#
# ...

# %%
from fastapi import FastAPI, HTTPException
from pydantic import BaseModel
from fastapi.middleware.cors import CORSMiddleware
import json
import google.generativeai as genai
from langchain.vectorstores import FAISS
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings

app = FastAPI()

# Enable CORS for frontend integration
app.add_middleware(
    CORSMiddleware,
    allow_origins=["*"],  # Allows all origins
    allow_credentials=True,
    allow_methods=["*"],  # Allows all HTTP methods
    allow_headers=["*"],  # Allows all headers
)

# Initialize HuggingFaceEmbeddings with Arabic support
hf_embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2")

# Configure Gemini API
genai.configure(api_key="AIzaSyAPlH0QYNq-bAManF02KQ1fSjvhp4H_bfs")  # Replace with your actual API key
gemini_model = genai.GenerativeModel("gemini-1.5-flash")

# Function to extract text from JSON file
def extract_text_from_json(json_path):
    with open(json_path, 'r', encoding='utf-8') as file:
        data = json.load(file)
        text = json.dumps(data, ensure_ascii=False, indent=2)
    return text

# Load text from JSON file
json_path = "/content/konbert-output-efe6d469.json"
json_text = extract_text_from_json(json_path)

# Improved text splitting for Arabic text
splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50, separators=[".", "؟", "!", "\n"])
text_chunks = splitter.split_text(json_text)

# Store text embeddings in FAISS
vector_store = FAISS.from_texts(text_chunks, hf_embeddings)

# Function to retrieve relevant text from JSON
def retrieve_relevant_text(query):
    results = vector_store.similarity_search(query, k=3)
    return " ".join([doc.page_content for doc in results])

# Pydantic model for input
display_text = "AI chatbot"

class QueryInput(BaseModel):
    query: str

@app.post("/ask")
async def ask_gemini_endpoint(query_input: QueryInput):
    query = query_input.query
    if not query.strip():
        raise HTTPException(status_code=400, detail="Error please enter correct input.")

    context = retrieve_relevant_text(query)
    prompt = f"Based on the following data:\n{context}\nAnswer this question: {query}"

    response = gemini_model.generate_content(prompt)
    return {"response": response.text if hasattr(response, "text") else response}

@app.get("/")
async def root():
    return {"message": "Welcome to SAF Chatbot"}
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.7/30.7 MB 54.2 MB/s eta 0:00:00
# ...
